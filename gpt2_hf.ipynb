# %% [markdown]
# # Building a simple generating model using HF pipeline function

# %%
pip install huggingface_hub
# Out:
# Requirement already satisfied: huggingface_hub in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (0.36.0)
# Requirement already satisfied: filelock in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from huggingface_hub) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from huggingface_hub) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from huggingface_hub) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from huggingface_hub) (6.0.1)
# Requirement already satisfied: requests in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from huggingface_hub) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from huggingface_hub) (4.66.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from huggingface_hub) (4.12.2)
# Requirement already satisfied: colorama in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from tqdm>=4.42.1->huggingface_hub) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from requests->huggingface_hub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from requests->huggingface_hub) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from requests->huggingface_hub) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from requests->huggingface_hub) (2024.6.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install transformers
# Out:
# Requirement already satisfied: transformers in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (4.57.1)
# Requirement already satisfied: filelock in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from transformers) (2.3.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.12.2)
# Requirement already satisfied: colorama in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers) (2024.6.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install gradio
# Out:
# Requirement already satisfied: gradio in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (5.29.1)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from gradio) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from gradio) (4.9.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from gradio) (0.121.2)
# Requirement already satisfied: ffmpy in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from gradio) (0.5.0)
# Requirement already satisfied: gradio-client==1.10.1 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from gradio) (1.10.1)
# Requirement already satisfied: groovy~=0.1 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from gradio) (0.1.2)
# Requirement already satisfied: httpx>=0.24.1 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from gradio) (0.27.0)
# Requirement already satisfied: huggingface-hub>=0.28.1 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from gradio) (0.36.0)
# Requirement already satisfied: jinja2<4.0 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from gradio) (3.1.4)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from gradio) (2.1.5)
# Requirement already satisfied: numpy<3.0,>=1.0 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from gradio) (2.3.4)
# Requirement already satisfied: orjson~=3.0 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from gradio) (3.10.18)
# Requirement already satisfied: packaging in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from gradio) (24.0)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from gradio) (2.2.3)
# Requirement already satisfied: pillow<12.0,>=8.0 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from gradio) (10.3.0)
# Requirement already satisfied: pydantic<2.12,>=2.0 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from gradio) (2.11.4)
# Requirement already satisfied: pydub in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from gradio) (0.0.20)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from gradio) (6.0.1)
# Requirement already satisfied: ruff>=0.9.3 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from gradio) (0.11.10)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from gradio) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from gradio) (0.46.2)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from gradio) (0.12.5)
# Requirement already satisfied: typer<1.0,>=0.12 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from gradio) (0.15.4)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from gradio) (4.12.2)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from gradio) (0.34.2)
# Requirement already satisfied: fsspec in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from gradio-client==1.10.1->gradio) (2025.3.0)
# Requirement already satisfied: websockets<16.0,>=10.0 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from gradio-client==1.10.1->gradio) (15.0.1)
# Requirement already satisfied: idna>=2.8 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.1)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from fastapi<1.0,>=0.115.2->gradio) (0.0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2024.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from pydantic<2.12,>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from pydantic<2.12,>=2.0->gradio) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from pydantic<2.12,>=2.0->gradio) (0.4.0)
# Requirement already satisfied: click<8.2,>=8.0.0 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from typer<1.0,>=0.12->gradio) (13.7.1)
# Requirement already satisfied: colorama in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from click<8.2,>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: certifi in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.24.1->gradio) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.24.1->gradio) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub>=0.28.1->gradio) (3.18.0)
# Requirement already satisfied: requests in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub>=0.28.1->gradio) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub>=0.28.1->gradio) (4.66.4)
# Requirement already satisfied: six>=1.5 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from requests->huggingface-hub>=0.28.1->gradio) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hasna\appdata\local\programs\python\python312\lib\site-packages (from requests->huggingface-hub>=0.28.1->gradio) (2.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# ## Using HF pipeline()

# %%
from transformers import pipeline, infer_device
device = infer_device()

# %%
# Loding model and importing gradio
import gradio as gr
generator = pipeline(
    "text-generation",
    model="codelion/gpt-2-70m",
    device=device
)
# Out:
# config.json:   0%|          | 0.00/750 [00:00<?, ?B/s]
# C:\Users\hasna\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\hasna\.cache\huggingface\hub\models--codelion--gpt-2-70m. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/256M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/119 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/475 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/99.0 [00:00<?, ?B/s]
# Device set to use cpu

# %% [markdown]
# ## Function for gradio

# %%
# function for gradio
def generate_response(user_input):
  output = generator(
      user_input,
      max_length=80,
      num_return_sequences=1,
      truncation=True
  )

  return output[0]["generated_text"]


with gr.Blocks() as demo:
  gr.Markdown("## 🔥 Simple GPT-2 Chat Interface")

  with gr.Row():
        user_input = gr.Textbox(
            label="Your Message",
            placeholder="Type something...",
            lines=2
        )
  generate_btn = gr.Button("Generate")
    
  output_box = gr.Textbox(
        label="Model Response",
        lines=5
    )
  
  

  generate_btn.click(
      fn=generate_response,
      inputs=user_input,
      outputs=output_box
    )

demo.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://4257318efe996e739c.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://4257318efe996e739c.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=80) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=80) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
