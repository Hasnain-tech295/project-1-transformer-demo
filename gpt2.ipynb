# %% [markdown]
# <a href="https://colab.research.google.com/github/Hasnain-tech295/project-1-transformer-demo/blob/main/gpt2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install huggingface_hub

# %%
# !pip install transformers

# %%
# !pip install gradio

# %%
from huggingface_hub import notebook_login
notebook_login()

# %% [markdown]
# # Using pipeline() function

# %%
import gradio as gr
from transformers import pipeline, infer_device

# %%
# load model
device = infer_device()
generator = pipeline(
    "text-generation",
    model="openai-community/gpt2",
    device=device
)
# Out:
# Device set to use cpu

# %%
# function for gradio
def generate_response(user_input):
  output = generator(
      user_input,
      max_length=80,
      num_return_sequences=1,
      truncation=True
  )

  return output[0]["generated_text"]

# %%
# Gradio UI
with gr.Blocks() as demo:
  gr.Markdown("## 🔥 Simple GPT-2 Chat Interface")

  with gr.Row():
        user_input = gr.Textbox(
            label="Your Message",
            placeholder="Type something...",
            lines=2
        )
  output_box = gr.Textbox(
        label="Model Response",
        lines=5
    )

  generate_btn = gr.Button("Generate")

  generate_btn.click(
      fn=generate_response,
      inputs=user_input,
      outputs=output_box
    )

demo.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://e92bc706891f718739.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://e92bc706891f718739.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
